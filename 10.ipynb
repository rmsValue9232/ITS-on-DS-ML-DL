# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn import datasets

# %%
def head(X: list, n = 5) -> list:
    """
    return `n` (default is 5) first rows of a 2D list

    `X` : The 2D list
    `n` : number of first rows
    """
    return X[:n]

def tail(X: list, n = 5) -> list:
    """
    return `n` (default is 5) last rows of a 2D list

    `X` : The 2D list
    `n` : number of last rows
    """
    return X[(-n):]

# %%
irisset = datasets.load_iris()
X = irisset.data[:100, :2]
print(head(X))
z = irisset.target[:100]
print(head(z))
# Out:
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]
# [0 0 0 0 0]

# %%
clf = svm.SVC(kernel = "linear", C = 0.5)
clf.fit(X,z)
w = clf.coef_[0]
print(w)
# Out:
# [ 1.99951861 -1.99996194]

# %%
xpoints = np.linspace(4, 7)
ypoints = -(w[0]*xpoints + clf.intercept_[0])/w[1]
plt.plot(xpoints, ypoints, "g-")
plt.scatter(X[:,0], X[:, 1], c = z)
plt.suptitle("SVM on IRIS data")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.grid(1, which="both")
plt.axis("tight")
plt.show()
