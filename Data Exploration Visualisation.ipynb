# %% [markdown]
# ### Data Exploration Visualisation
# #### Using `numpy`, `pandas`, `seaborn`, `matplotlib`

# %% [markdown]
# ----
# ##### I. First try `pandas`

# %%
import pandas as pd

# %%
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.head(12)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.sample(5)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 105           7.6          3.0           6.6          2.1  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 3             4.6          3.1           1.5          0.2     Setosa
# 108           6.7          2.5           5.8          1.8  Virginica
# 25            5.0          3.0           1.6          0.2     Setosa

# %%
iris.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
iris[25:35]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 25           5.0          3.0           1.6          0.2  Setosa
# 26           5.0          3.4           1.6          0.4  Setosa
# 27           5.2          3.5           1.5          0.2  Setosa
# 28           5.2          3.4           1.4          0.2  Setosa
# 29           4.7          3.2           1.6          0.2  Setosa
# 30           4.8          3.1           1.6          0.2  Setosa
# 31           5.4          3.4           1.5          0.4  Setosa
# 32           5.2          4.1           1.5          0.1  Setosa
# 33           5.5          4.2           1.4          0.2  Setosa
# 34           4.9          3.1           1.5          0.2  Setosa

# %%
iris[0:10]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
type(iris.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
type(iris[0:10])
# Out:
# pandas.core.frame.DataFrame

# %%
type(iris.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
type(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# NoneType

# %%
iris.columns[0:2]
# Out:
# Index(['sepal.length', 'sepal.width'], dtype='object')

# %%
iris[["variety", "sepal.length"]]
# Out:
#        variety  sepal.length
# 0       Setosa           5.1
# 1       Setosa           4.9
# 2       Setosa           4.7
# 3       Setosa           4.6
# 4       Setosa           5.0
# ..         ...           ...
# 145  Virginica           6.7
# 146  Virginica           6.3
# 147  Virginica           6.5
# 148  Virginica           6.2
# 149  Virginica           5.9
#
# [150 rows x 2 columns]

# %%
iris[["variety", "sepal.length"]][2:10]
# Out:
#   variety  sepal.length
# 2  Setosa           4.7
# 3  Setosa           4.6
# 4  Setosa           5.0
# 5  Setosa           5.4
# 6  Setosa           4.6
# 7  Setosa           5.0
# 8  Setosa           4.4
# 9  Setosa           4.9

# %%
iris[2:10][["variety", "sepal.length"]]
# Out:
#   variety  sepal.length
# 2  Setosa           4.7
# 3  Setosa           4.6
# 4  Setosa           5.0
# 5  Setosa           5.4
# 6  Setosa           4.6
# 7  Setosa           5.0
# 8  Setosa           4.4
# 9  Setosa           4.9

# %%
iris[2:10][["variety", "sepal.length"]].equals(iris[["variety", "sepal.length"]][2:10])
# Out:
# True

# %%
iris.sort_values("sepal.length", ascending=True)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 13            4.3          3.0           1.1          0.1     Setosa
# 42            4.4          3.2           1.3          0.2     Setosa
# 38            4.4          3.0           1.3          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 41            4.5          2.3           1.3          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  Virginica
# 118           7.7          2.6           6.9          2.3  Virginica
# 117           7.7          3.8           6.7          2.2  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica
#
# [150 rows x 5 columns]

# %%
iris.sort_values("petal.length", ascending=True)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 22            4.6          3.6           1.0          0.2     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 14            5.8          4.0           1.2          0.2     Setosa
# 35            5.0          3.2           1.2          0.2     Setosa
# 36            5.5          3.5           1.3          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 131           7.9          3.8           6.4          2.0  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 117           7.7          3.8           6.7          2.2  Virginica
# 122           7.7          2.8           6.7          2.0  Virginica
# 118           7.7          2.6           6.9          2.3  Virginica
#
# [150 rows x 5 columns]

# %%
# Purely index based locating only
iris.iloc[10:20]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa

# %%
type(iris.iloc[10:20])
# Out:
# pandas.core.frame.DataFrame

# %%
# Purely label(s) and boolean based locating only
iris.loc[iris["variety"]=="Virginica"]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
iris.loc[iris["sepal.width"] == 3.0]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 1             4.9          3.0           1.4          0.2      Setosa
# 12            4.8          3.0           1.4          0.1      Setosa
# 13            4.3          3.0           1.1          0.1      Setosa
# 25            5.0          3.0           1.6          0.2      Setosa
# 38            4.4          3.0           1.3          0.2      Setosa
# 45            4.8          3.0           1.4          0.3      Setosa
# 61            5.9          3.0           4.2          1.5  Versicolor
# 66            5.6          3.0           4.5          1.5  Versicolor
# 75            6.6          3.0           4.4          1.4  Versicolor
# 77            6.7          3.0           5.0          1.7  Versicolor
# 84            5.4          3.0           4.5          1.5  Versicolor
# 88            5.6          3.0           4.1          1.3  Versicolor
# ...

# %%
iris[iris["sepal.width"] == 3.0].equals(iris.loc[iris["sepal.width"]==3.0])
# Out:
# True

# %%
iris.loc[iris["sepal.width"] == 3.0][iris["sepal.length"] < 5.0]
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_19644\3105631126.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   iris.loc[iris["sepal.width"] == 3.0][iris["sepal.length"] < 5.0]
#     sepal.length  sepal.width  petal.length  petal.width variety
# 1            4.9          3.0           1.4          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 38           4.4          3.0           1.3          0.2  Setosa
# 45           4.8          3.0           1.4          0.3  Setosa

# %%
iris["variety"].value_counts()
# returns a series of counts of unique values in that column
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
ig = iris.groupby("variety")
ig

# %%
ig.first()
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.1          3.5           1.4          0.2
# Versicolor           7.0          3.2           4.7          1.4
# Virginica            6.3          3.3           6.0          2.5

# %%
print(ig)

# %%
ig.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           1.4          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 53            5.5          2.3           4.0          1.3  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica
# 101           5.8          2.7           5.1          1.9   Virginica
# ...

# %%
ig.head(1)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica

# %%
a = ig.get_group("Setosa")
a
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
ig.nth(1)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 1             4.9          3.0           1.4          0.2      Setosa
# 51            6.4          3.2           4.5          1.5  Versicolor
# 101           5.8          2.7           5.1          1.9   Virginica

# %%
ig.nth[1]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 1             4.9          3.0           1.4          0.2      Setosa
# 51            6.4          3.2           4.5          1.5  Versicolor
# 101           5.8          2.7           5.1          1.9   Virginica

# %%
ig.nth[3:7]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             4.6          3.4           1.4          0.3      Setosa
# 53            5.5          2.3           4.0          1.3  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# 55            5.7          2.8           4.5          1.3  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# 103           6.3          2.9           5.6          1.8   Virginica
# 104           6.5          3.0           5.8          2.2   Virginica
# 105           7.6          3.0           6.6          2.1   Virginica
# 106           4.9          2.5           4.5          1.7   Virginica

# %%
print("petal.length sum:",iris["petal.length"].sum())
print("petal.length mean:",iris["petal.length"].mean())
print("petal.length median:",iris["petal.length"].median())
print("petal.length max:",iris["petal.length"].max())
print("petal.length min:",iris["petal.length"].min())
print("petal.length std:",iris["petal.length"].std())
# Out:
# petal.length sum: 563.7
# petal.length mean: 3.7580000000000005
# petal.length median: 4.35
# petal.length max: 6.9
# petal.length min: 1.0
# petal.length std: 1.7652982332594667

# %%
iris[iris.columns[0:4]].corr()
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
type(iris[iris.columns[0:4]].corr())
# Out:
# pandas.core.frame.DataFrame

# %%
iris["ratio"] = iris["sepal.width"]/iris["petal.width"]
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#          ratio
# 0    17.500000
# 1    15.000000
# 2    16.000000
# 3    15.500000
# 4    18.000000
# ..         ...
# 145   1.304348
# ...

# %%
iris.drop(columns=["ratio"])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.rename(columns={"petal.length":"PL", "sepal.length":"SL"}, inplace=False)
# inplace ensures that renaming does not occur in the original variable, and this effectively returns a new dataFrame, copied from iris variable
# Out:
#       SL  sepal.width   PL  petal.width    variety      ratio
# 0    5.1          3.5  1.4          0.2     Setosa  17.500000
# 1    4.9          3.0  1.4          0.2     Setosa  15.000000
# 2    4.7          3.2  1.3          0.2     Setosa  16.000000
# 3    4.6          3.1  1.5          0.2     Setosa  15.500000
# 4    5.0          3.6  1.4          0.2     Setosa  18.000000
# ..   ...          ...  ...          ...        ...        ...
# 145  6.7          3.0  5.2          2.3  Virginica   1.304348
# 146  6.3          2.5  5.0          1.9  Virginica   1.315789
# 147  6.5          3.0  5.2          2.0  Virginica   1.500000
# 148  6.2          3.4  5.4          2.3  Virginica   1.478261
# 149  5.9          3.0  5.1          1.8  Virginica   1.666667
#
# [150 rows x 6 columns]
